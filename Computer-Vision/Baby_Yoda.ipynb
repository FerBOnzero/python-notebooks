# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
image = cv2.imread('/Users/omar/Documents/Baby_Yoda.jpeg')
plt.imshow(image)
plt.show()

# %%
image.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-37e5e7d86f91> in <module>
# ----> 1 image.to_array()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_array'
